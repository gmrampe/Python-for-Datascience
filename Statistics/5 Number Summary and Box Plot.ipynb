# %% [markdown]
# # 5 Number Summary and Box Plot

# %% [raw]
# ## Minimum
# ## Maximum
# # median
# # Q1
# # Q3
# #IQR(Inter Quartile Range)

# %%
import numpy as np
l_marks=[45,32,45,28,98,99,67,54,23,45,97,22,49]
minimum,Q1,median,Q3,maximum=np.quantile(l_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum
# Out:
# 22.0

# %%
Q1
# Out:
# 32.0

# %%
median
# Out:
# 45.0

# %%
Q3
# Out:
# 67.0

# %%
maximum
# Out:
# 99.0

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 35.0

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# -20.5

# %%
higher_fence
# Out:
# 119.5

# %%
import seaborn as sns
sns.boxplot(l_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-100,-120,22,33,23,32,34,34,45,45,56,65,65,67,67,68,69,59,89,78,95,97,94,1000,1200,1300]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-100,-120,22,33,23,32,34,34,45,45,56,65,65,67,67,68,69,59,89,78,95,97,94,100,120,130]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
