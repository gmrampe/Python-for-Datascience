# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('swiggy.csv')

# %%
df
# Out:
#             id                      name      city rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar     --  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar    4.4      50+ ratings
# 2       158203         theka coffee desi    Abohar    3.8     100+ ratings
# 3       187912                 Singh Hut    Abohar    3.7      20+ ratings
# 4       543530             GRILL MASTERS    Abohar     --  Too Few Ratings
# ...        ...                       ...       ...    ...              ...
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost                     cuisine          lic_no  \
# ...

# %%
df.shape
# Out:
# (148541, 11)

# %%
df.columns
# Out:
# Index(['id', 'name', 'city', 'rating', 'rating_count', 'cost', 'cuisine',
#        'lic_no', 'link', 'address', 'menu'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148541 entries, 0 to 148540
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148541 non-null  int64
#  1   name          148455 non-null  object
#  2   city          148541 non-null  object
#  3   rating        148455 non-null  object
#  4   rating_count  148455 non-null  object
#  5   cost          148410 non-null  object
#  6   cuisine       148442 non-null  object
#  7   lic_no        148312 non-null  object
#  8   link          148541 non-null  object
#  9   address       148455 non-null  object
#  10  menu          148541 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 12.5+ MB

# %%
df.isnull().sum()
# Out:
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# lic_no          229
# link              0
# address          86
# menu              0
# dtype: int64

# %%
df.sample(5)
# Out:
#             id                  name            city rating     rating_count  \
# 96076   493197          Bong Chinese  Dumdum,Kolkata     --  Too Few Ratings
# 39698   460826            Chettinese   Porur,Chennai     --  Too Few Ratings
# 135714  130303  DesiDude Restro Cafe          Rohtak    3.2      50+ ratings
# 69805   513628  The Roar Gym Kitchen         Gwalior     --  Too Few Ratings
# 89110   535636             Swad Kuri  Howrah,Kolkata     --  Too Few Ratings
#
#          cost                 cuisine          lic_no  \
# 96076   ₹ 250           Chinese,Combo  22822132000080
# 39698   ₹ 400         Chinese,Biryani         license
# 135714  ₹ 250        Snacks,Beverages         license
# 69805   ₹ 250  Healthy Food,Fast Food  21422570000172
# 89110   ₹ 150    North Indian,Chinese  22821008002399
#
#                                                      link  \
# 96076   https://www.swiggy.com/restaurants/bong-chines...
# ...

# %%
df.head()
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# ...

# %%
df.describe()
# Out:
#                   id
# count  148541.000000
# mean   363466.378912
# std    167890.977174
# min       211.000000
# 25%    233320.000000
# 50%    412628.000000
# 75%    502223.000000
# max    581031.000000

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, city, rating, rating_count, cost, cuisine, lic_no, link, address, menu]
# Index: []

# %%
df.describe(include='all')
# Out:
#                    id            name     city  rating     rating_count  \
# count   148541.000000          148455   148541  148455           148455
# unique            NaN          112818      821      42                8
# top               NaN  Domino's Pizza  Bikaner      --  Too Few Ratings
# freq              NaN             442     1666   87014            87014
# mean    363466.378912             NaN      NaN     NaN              NaN
# std     167890.977174             NaN      NaN     NaN              NaN
# min        211.000000             NaN      NaN     NaN              NaN
# 25%     233320.000000             NaN      NaN     NaN              NaN
# 50%     412628.000000             NaN      NaN     NaN              NaN
# 75%     502223.000000             NaN      NaN     NaN              NaN
# max     581031.000000             NaN      NaN     NaN              NaN
#
#           cost               cuisine   lic_no  \
# count   148410                148442   148312
# ...

# %%
df.drop('lic_no',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
#
#             cuisine                                               link  \
# 0  Beverages,Pizzas  https://www.swiggy.com/restaurants/ab-foods-po...
# 1     Sweets,Bakery  https://www.swiggy.com/restaurants/janta-sweet...
#
#                                              address              menu
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...  Menu/567335.json
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...  Menu/531342.json

# %%
df.columns
# Out:
# Index(['id', 'name', 'city', 'rating', 'rating_count', 'cost', 'cuisine',
#        'link', 'address', 'menu'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# link              0
# address          86
# menu              0
# dtype: int64

# %%
df['cost']
# Out:
# 0         ₹ 200
# 1         ₹ 200
# 2         ₹ 100
# 3         ₹ 250
# 4         ₹ 250
#           ...
# 148536    ₹ 200
# 148537    ₹ 300
# 148538    ₹ 300
# 148539    ₹ 250
# 148540    ₹ 200
# Name: cost, Length: 148541, dtype: object

# %%
df[df['cost'].isnull()]
# Out:
#             id                          name                city rating  \
# 4966    132295                   Chinese Hut               Akola    3.7
# 4983    134728      Zamzam Family Restaurant               Akola    3.2
# 24835   131745         Anvita Veg Restaurant                Beed    3.7
# 24836   132958               Bansi Pav bhaji                Beed    3.6
# 24838   131755  Sai Prasad Family Restaurant                Beed    3.8
# ...        ...                           ...                 ...    ...
# 141151  222071            M/S K/K Restaurant              Tezpur     --
# 141568  463812                           NaN  Thiruvananthapuram    NaN
# 142842  304862                  AAKASH FOODS      Tiruvannamalai     --
# 143949  462679               MOMO MAGIC CAFE              Ujjain     --
# 148271  148773                  Hashtag Cafe              Wardha     --
#
#            rating_count cost                    cuisine  \
# ...

# %%
df[df['rating'].isnull()]
# Out:
#             id name                       city rating rating_count cost  \
# 31044   397961  NaN  Greater Mohali,Chandigarh    NaN          NaN  NaN
# 32912   308071  NaN        West Chd,Chandigarh    NaN          NaN  NaN
# 33046   308662  NaN        West Chd,Chandigarh    NaN          NaN  NaN
# 33488   170889  NaN       South Chd,Chandigarh    NaN          NaN  NaN
# 36492   390394  NaN        George Town,Chennai    NaN          NaN  NaN
# ...        ...  ...                        ...    ...          ...  ...
# 137122  256827  NaN                     Satara    NaN          NaN  NaN
# 137546  567595  NaN                   Shillong    NaN          NaN  NaN
# 137614  116615  NaN                 Shivamogga    NaN          NaN  NaN
# 138380  401760  NaN                      Sirsa    NaN          NaN  NaN
# 141568  463812  NaN         Thiruvananthapuram    NaN          NaN  NaN
#
#        cuisine                                               link address  \
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#             id                      name      city rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar     --  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar    4.4      50+ ratings
# 2       158203         theka coffee desi    Abohar    3.8     100+ ratings
# 3       187912                 Singh Hut    Abohar    3.7      20+ ratings
# 4       543530             GRILL MASTERS    Abohar     --  Too Few Ratings
# ...        ...                       ...       ...    ...              ...
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost                     cuisine  \
# ...

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# city            0
# rating          0
# rating_count    0
# cost            0
# cuisine         0
# link            0
# address         0
# menu            0
# dtype: int64

# %%
df.shape
# Out:
# (148398, 10)

# %%
df['cost'].head(20)
# Out:
# 0     ₹ 200
# 1     ₹ 200
# 2     ₹ 100
# 3     ₹ 250
# 4     ₹ 250
# 5     ₹ 200
# 6     ₹ 150
# 7     ₹ 100
# 8     ₹ 100
# 9     ₹ 200
# 10    ₹ 300
# 11    ₹ 100
# 12    ₹ 200
# 13    ₹ 100
# 14    ₹ 300
# 15    ₹ 300
# 16    ₹ 200
# 17    ₹ 200
# 18    ₹ 100
# 19    ₹ 300
# Name: cost, dtype: object

# %%
df['cost'].tail(20)
# Out:
# 148521    ₹ 150
# 148522    ₹ 200
# 148523    ₹ 200
# 148524    ₹ 300
# 148525    ₹ 250
# 148526    ₹ 200
# 148527    ₹ 200
# 148528    ₹ 120
# 148529    ₹ 150
# 148530    ₹ 200
# 148531    ₹ 200
# 148532    ₹ 300
# 148533    ₹ 250
# 148534    ₹ 100
# 148535    ₹ 300
# 148536    ₹ 200
# 148537    ₹ 300
# 148538    ₹ 300
# 148539    ₹ 250
# 148540    ₹ 200
# Name: cost, dtype: object

# %%
df['cost']=df['cost'].str.replace('₹','').str.strip()
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\1236784869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cost']=df['cost'].str.replace('₹','').str.strip()

# %%
df['cost']
# Out:
# 0         200
# 1         200
# 2         100
# 3         250
# 4         250
#          ...
# 148536    200
# 148537    300
# 148538    300
# 148539    250
# 148540    200
# Name: cost, Length: 148398, dtype: object

# %%
df['cost'] = df['cost'].astype(int)
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\3109390103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cost'] = df['cost'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148398 entries, 0 to 148540
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148398 non-null  int64
#  1   name          148398 non-null  object
#  2   city          148398 non-null  object
#  3   rating        148398 non-null  object
#  4   rating_count  148398 non-null  object
#  5   cost          148398 non-null  int32
#  6   cuisine       148398 non-null  object
#  7   link          148398 non-null  object
#  8   address       148398 non-null  object
#  9   menu          148398 non-null  object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 11.9+ MB

# %%
df['rating']
# Out:
# 0          --
# 1         4.4
# 2         3.8
# 3         3.7
# 4          --
#          ...
# 148536     --
# 148537     --
# 148538     --
# 148539     --
# 148540     --
# Name: rating, Length: 148398, dtype: object

# %%
df['rating'].head(20)
# Out:
# 0      --
# 1     4.4
# 2     3.8
# 3     3.7
# 4      --
# 5     3.6
# 6     4.0
# 7      --
# 8     4.2
# 9      --
# 10     --
# 11    4.2
# 12     --
# 13     --
# 14    4.4
# 15     --
# 16    4.0
# 17     --
# 18     --
# 19    4.7
# Name: rating, dtype: object

# %%
df['rating'].tail(20)
# Out:
# 148521    2.6
# 148522     --
# 148523     --
# 148524     --
# 148525     --
# 148526     --
# 148527     --
# 148528     --
# 148529     --
# 148530     --
# 148531     --
# 148532     --
# 148533     --
# 148534     --
# 148535     --
# 148536     --
# 148537     --
# 148538     --
# 148539     --
# 148540     --
# Name: rating, dtype: object

# %%
df['rating'].sample(20)
# Out:
# 133004    4.2
# 123594     --
# 49034      --
# 110378     --
# 139417    4.4
# 6807       --
# 11133     3.9
# 2026      3.7
# 73040      --
# 117508     --
# 128520    4.0
# 49587     4.2
# 32848      --
# 47035     3.9
# 7869       --
# 126115    4.1
# 44374      --
# 92021      --
# 131328     --
# 46217     4.4
# Name: rating, dtype: object

# %%
# Replace '--' with NaN
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\2216456702.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df['rating']
# Out:
# 0         NaN
# 1         4.4
# 2         3.8
# 3         3.7
# 4         NaN
#          ...
# 148536    NaN
# 148537    NaN
# 148538    NaN
# 148539    NaN
# 148540    NaN
# Name: rating, Length: 148398, dtype: float64

# %%
# Calculate mean of remaining values
mean = df['rating'].mean()

# %%
mean
# Out:
# 3.89455072369385

# %%
# Replace NaN values with mean
df['rating'] = df['rating'].fillna(mean)
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\3759123408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].fillna(mean)

# %%
df
# Out:
#             id                      name      city    rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar  3.894551  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar  4.400000      50+ ratings
# 2       158203         theka coffee desi    Abohar  3.800000     100+ ratings
# 3       187912                 Singh Hut    Abohar  3.700000      20+ ratings
# 4       543530             GRILL MASTERS    Abohar  3.894551  Too Few Ratings
# ...        ...                       ...       ...       ...              ...
# 148536  553122          The Food Delight  Yavatmal  3.894551  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal  3.894551  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal  3.894551  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal  3.894551  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal  3.894551  Too Few Ratings
#
# ...

# %%
df['rating']
# Out:
# 0         3.894551
# 1         4.400000
# 2         3.800000
# 3         3.700000
# 4         3.894551
#             ...
# 148536    3.894551
# 148537    3.894551
# 148538    3.894551
# 148539    3.894551
# 148540    3.894551
# Name: rating, Length: 148398, dtype: float64

# %%
df['rating'].tail(20)
# Out:
# 148521    2.600000
# 148522    3.894551
# 148523    3.894551
# 148524    3.894551
# 148525    3.894551
# 148526    3.894551
# 148527    3.894551
# 148528    3.894551
# 148529    3.894551
# 148530    3.894551
# 148531    3.894551
# 148532    3.894551
# 148533    3.894551
# 148534    3.894551
# 148535    3.894551
# 148536    3.894551
# 148537    3.894551
# 148538    3.894551
# 148539    3.894551
# 148540    3.894551
# Name: rating, dtype: float64

# %%
df['rating']=df['rating'].astype(int)
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\3733812309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating']=df['rating'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148398 entries, 0 to 148540
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148398 non-null  int64
#  1   name          148398 non-null  object
#  2   city          148398 non-null  object
#  3   rating        148398 non-null  int32
#  4   rating_count  148398 non-null  object
#  5   cost          148398 non-null  int32
#  6   cuisine       148398 non-null  object
#  7   link          148398 non-null  object
#  8   address       148398 non-null  object
#  9   menu          148398 non-null  object
# dtypes: int32(2), int64(1), object(7)
# memory usage: 11.3+ MB

# %%
df.head()
# Out:
#        id               name    city  rating     rating_count  cost  \
# 0  567335     AB FOODS POINT  Abohar       3  Too Few Ratings   200
# 1  531342  Janta Sweet House  Abohar       4      50+ ratings   200
# 2  158203  theka coffee desi  Abohar       3     100+ ratings   100
# 3  187912          Singh Hut  Abohar       3      20+ ratings   250
# 4  543530      GRILL MASTERS  Abohar       3  Too Few Ratings   250
#
#                       cuisine  \
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# 4  https://www.swiggy.com/restaurants/grill-maste...
#
# ...

# %%
df['city'].sample(5)
# Out:
# 88109             Vyttila,Kochi
# 13909    Banashankari,Bangalore
# 24751                  Bathinda
# 2926      Gandhinagar,Ahmedabad
# 6516                   Amritsar
# Name: city, dtype: object

# %%
df.drop('menu',axis=1,inplace=True)
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\3756713952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('menu',axis=1,inplace=True)

# %%
df
# Out:
#             id                      name      city  rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar       3  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar       4      50+ ratings
# 2       158203         theka coffee desi    Abohar       3     100+ ratings
# 3       187912                 Singh Hut    Abohar       3      20+ ratings
# 4       543530             GRILL MASTERS    Abohar       3  Too Few Ratings
# ...        ...                       ...       ...     ...              ...
# 148536  553122          The Food Delight  Yavatmal       3  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal       3  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal       3  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal       3  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal       3  Too Few Ratings
#
#         cost                     cuisine  \
# ...

# %%
df.isnull()
# Out:
#            id   name   city  rating  rating_count   cost  cuisine   link  \
# 0       False  False  False   False         False  False    False  False
# 1       False  False  False   False         False  False    False  False
# 2       False  False  False   False         False  False    False  False
# 3       False  False  False   False         False  False    False  False
# 4       False  False  False   False         False  False    False  False
# ...       ...    ...    ...     ...           ...    ...      ...    ...
# 148536  False  False  False   False         False  False    False  False
# 148537  False  False  False   False         False  False    False  False
# 148538  False  False  False   False         False  False    False  False
# 148539  False  False  False   False         False  False    False  False
# 148540  False  False  False   False         False  False    False  False
#
#         address
# 0         False
# 1         False
# 2         False
# 3         False
# ...

# %%
df['name'].describe()
# Out:
# count             148398
# unique            112772
# top       Domino's Pizza
# freq                 442
# Name: name, dtype: object

# %%
df['name'].value_counts()
# Out:
# Domino's Pizza                                     442
# Pizza Hut                                          319
# KFC                                                309
# Kwality Walls Frozen Dessert and Ice Cream Shop    300
# Baskin Robbins                                     274
#                                                   ...
# Seema Healthy Kitchen                                1
# SARANSH DI HATTI                                     1
# FEEDME                                               1
# Doojee                                               1
# Lazeez kitchen                                       1
# Name: name, Length: 112772, dtype: int64

# %%
df.drop_duplicates()
# Out:
#             id                      name      city  rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar       3  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar       4      50+ ratings
# 2       158203         theka coffee desi    Abohar       3     100+ ratings
# 3       187912                 Singh Hut    Abohar       3      20+ ratings
# 4       543530             GRILL MASTERS    Abohar       3  Too Few Ratings
# ...        ...                       ...       ...     ...              ...
# 148536  553122          The Food Delight  Yavatmal       3  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal       3  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal       3  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal       3  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal       3  Too Few Ratings
#
#         cost                     cuisine  \
# ...

# %%
df.shape
# Out:
# (148398, 9)

# %%
df.drop('link',axis=1,inplace=True)
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\3424798725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('link',axis=1,inplace=True)

# %%
df
# Out:
#             id                      name      city  rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar       3  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar       4      50+ ratings
# 2       158203         theka coffee desi    Abohar       3     100+ ratings
# 3       187912                 Singh Hut    Abohar       3      20+ ratings
# 4       543530             GRILL MASTERS    Abohar       3  Too Few Ratings
# ...        ...                       ...       ...     ...              ...
# 148536  553122          The Food Delight  Yavatmal       3  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal       3  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal       3  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal       3  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal       3  Too Few Ratings
#
#         cost                     cuisine  \
# ...

# %%
df['address'].sample(100)
# Out:
# 112953    Keventers - Milkshakes and Desserts, Ground Fl...
# 28440     Next Level Cafe, Shop No. 1591,Gali No.12,Om N...
# 124663    24K FOOD POINT, OPP. SATHE PETROL PUMP, NEAR 2...
# 4         GRILL MASTERS, ADA Heights, Abohar - Hanumanga...
# 42633     Cream and crush, F1, MRA homes Emerald, No 75 ...
#                                 ...
# 143029    La Cream, No.5 G/2-1,11th Cross East,Near HDFC...
# 10373     PADDU RANGA, Phase 7 JP Nagar, Bengaluru, Beng...
# 50205     Burger Panda, krishna nagar lal quarter main m...
# 76623     Apna Cafe, S1, Siri Residency, Marva Township,...
# 141093    Inaya Mughlai, NEAR KAMRUPIA NAMGHAR,TEZPUR,78...
# Name: address, Length: 100, dtype: object

# %%
# visualization

# %%
plt.figure(figsize = (4,6))
sns.set_style('white')
sns.displot(x='rating',data = df,color = 'g')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.set_style('white')
plt.hist(df['rating'][:10],bins = 10,color = 'b')
plt.xlabel('Rating')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\2085779751.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.hist(df['rating'][:10],bins = 10,color = 'b')

# %%
plt.figure(figsize=(8,6))
sns.set_style('white')
sns.countplot(df['rating'])
plt.show()

# %%
plt.figure(figsize=(7,8))
sns.set_style('dark')
sns.distplot(df['rating'])
plt.grid(True)
plt.show()
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\2823680881.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rating'])

# %%
sns.displot(df.rating)

# %%
sns.pairplot(data=df,hue ='rating')
plt.show()

# %%
plt.figure(figsize = (6,8))

df.groupby(['name'])['rating'].mean().sort_values(ascending = False)[:10].plot(kind = 'pie',
                                                                                           autopct = '%.2f%%')
plt.show()

# %%
plt.figure(figsize = (6,8))

df.groupby(['city'])['cost'].mean().sort_values(ascending = False)[:10].plot(kind = 'pie',
                                                                                           autopct = '%.2f%%')
plt.show()

# %%
df.head()
# Out:
#        id               name    city  rating     rating_count  cost  \
# 0  567335     AB FOODS POINT  Abohar       3  Too Few Ratings   200
# 1  531342  Janta Sweet House  Abohar       4      50+ ratings   200
# 2  158203  theka coffee desi  Abohar       3     100+ ratings   100
# 3  187912          Singh Hut  Abohar       3      20+ ratings   250
# 4  543530      GRILL MASTERS  Abohar       3  Too Few Ratings   250
#
#                       cuisine  \
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food
#
#                                              address
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...
# 2         theka coffee desi, sahtiya sadan road city
# 3    Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR
# 4  GRILL MASTERS, ADA Heights, Abohar - Hanumanga...

# %%
plt.figure(figsize = (6,8))

df.groupby(['city'])['rating'].mean().sort_values(ascending = False)[:10].plot(kind = 'pie',
                                                                                           autopct = '%.2f%%')
plt.show()

# %%
plt.figure(figsize = (6,8))

df.groupby(['rating_count'])['rating'].mean().sort_values(ascending = False)[:10].plot(kind = 'pie',
                                                                                           autopct = '%.2f%%')
plt.show()

# %%
df.groupby(['name'])['rating'].mean().sort_values(ascending = False)[:10].plot(kind = 'barh',color ='r')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set_style('dark')
pd.Series(df['cuisine'].value_counts(ascending = False)[:20].plot(kind = 'barh',color = 'darkblue'))
plt.title ('Most available cuisine',color = 'k')
plt.xlabel('restaraunt',color = 'k')
plt.ylabel('cuisine',color = 'k')
plt.show()

# %%
plt.figure(figsize= (8,9))
sns.color_palette('gray')
sns.set_style('white')
pd.Series(df['name'].value_counts(ascending = False)[:20].plot(kind = 'barh',color = 'grey'))
plt.title('Restaraunt',color = 'k')
plt.xlabel('Apperances',color = 'k')
plt.ylabel('Restaraunt',color = 'k')
plt.show()

# %%
plt.figure(figsize = (8,6))
pd.Series(df['rating'].value_counts(ascending = False).head(10).plot(kind = 'pie',autopct = '%.2f%%'))
plt.show()

# %%
plt.figure(figsize = (8,6))
SWIGGY = df.corr()
sns.heatmap(SWIGGY,annot=True)
plt.show()
# Out:
# C:\Users\rampe\AppData\Local\Temp\ipykernel_5556\3535677697.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   SWIGGY = df.corr()
